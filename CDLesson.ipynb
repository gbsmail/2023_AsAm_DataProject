# %% [markdown]
# Data Files: https://drive.google.com/drive/folders/1bRbcxJrJCAugoNigdrU6hVOSj646MYVs?usp=sharing

# %%
import pandas as pd

# %%
dfcensus = pd.read_csv("data/2020censussample.csv")
dfcensus
# Out:
#     Year        Borough  Community District Number  \
# 0   2020          Bronx                        201
# 1   2020          Bronx                        202
# 2   2020          Bronx                        203
# 3   2020       Brooklyn                        301
# 4   2020       Brooklyn                        302
# 5   2020       Brooklyn                        303
# 6   2020      Manhattan                        101
# 7   2020      Manhattan                        102
# 8   2020      Manhattan                        103
# 9   2020         Queens                        401
# 10  2020         Queens                        402
# 11  2020         Queens                        403
# 12  2020  Staten Island                        501
# 13  2020  Staten Island                        502
# 14  2020  Staten Island                        503
#
#                Community District Name Total Population   Asian
# 0           Bronx Community District 1          100,929     909
# ...

# %%
dfgarden = pd.read_csv("data/communitygardenssample.csv")
dfgarden
# Out:
#                                 Garden     Borough Community District
# 0             61 Franklin Street Garden   Brooklyn                 B01
# 1                         Greene Garden   Brooklyn                 B02
# 2           100 Quincy Community Garden   Brooklyn                 B03
# 3               Campos Community Garden  Manhattan                 M01
# 4    Carmen Pabon Del Aman- ecer Jardin  Manhattan                 M02
# ..                                  ...        ...                 ...
# 214                                 NaN        NaN                 NaN
# 215                                 NaN        NaN                 NaN
# 216                                 NaN        NaN                 NaN
# 217                                 NaN        NaN                 NaN
# 218                                 NaN        NaN                 NaN
#
# [219 rows x 3 columns]

# %%
dfshelter = pd.read_csv("data/homelesssheltersample.csv")
dfshelter
# Out:
#      Report Date   Borough  Community District  Adult Family Shelter  \
# 0       10/31/20     Bronx                 1.0                 189.0
# 1       10/31/20     Bronx                 2.0                 160.0
# 2       10/31/20     Bronx                 3.0                 258.0
# 3       10/31/20  Brooklyn                 1.0                 145.0
# 4       10/31/20  Brooklyn                 2.0                  78.0
# ...          ...       ...                 ...                   ...
# 3136         NaN       NaN                 NaN                   NaN
# 3137         NaN       NaN                 NaN                   NaN
# 3138         NaN       NaN                 NaN                   NaN
# 3139         NaN       NaN                 NaN                   NaN
# 3140         NaN       NaN                 NaN                   NaN
#
#       Adult Shelter  Adult Shelter Commercial Hotel  \
# 0              73.0                           140.0
# ...

# %%
dfsnap = pd.read_csv("data/snapbenefitssample.csv")
dfsnap
# Out:
#       Month    Borough Community District  BC_SNAP_Recipients  \
# 0    9/1/20  Manhattan                M01              2276.0
# 1    9/1/20  Manhattan                M02              2994.0
# 2    9/1/20  Manhattan                M03             37879.0
# 3    9/1/20      Bronx                B01             47212.0
# 4    9/1/20      Bronx                B02             23150.0
# ..      ...        ...                ...                 ...
# 667     NaN        NaN                NaN                 NaN
# 668     NaN        NaN                NaN                 NaN
# 669     NaN        NaN                NaN                 NaN
# 670     NaN        NaN                NaN                 NaN
# 671     NaN        NaN                NaN                 NaN
#
#      BC_SNAP_Households
# 0                1799.0
# 1                2438.0
# 2               26041.0
# 3               25740.0
# 4               12855.0
# ..                  ...
# 667                 NaN
# ...
