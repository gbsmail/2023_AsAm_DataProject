# %%
## import library
import pandas as pd

# %%
## import data 
df = pd.read_csv("data/EquityNYC_Data.csv")
df
# Out:
#        indicator_id             indicator_name  \
# 0               174  Accepted DHE Applications
# 1               174  Accepted DHE Applications
# 2               174  Accepted DHE Applications
# 3               174  Accepted DHE Applications
# 4               174  Accepted DHE Applications
# ...             ...                        ...
# 24320           251       Speed Cameras: Total
# 24321           251       Speed Cameras: Total
# 24322           251       Speed Cameras: Total
# 24323           251       Speed Cameras: Total
# 24324           251       Speed Cameras: Total
#
#                                domain                         agency_name  \
# 0      Economic Security and Mobility         Department of Finance (DOF)
# 1      Economic Security and Mobility         Department of Finance (DOF)
# 2      Economic Security and Mobility         Department of Finance (DOF)
# 3      Economic Security and Mobility         Department of Finance (DOF)
# ...

# %%
dfa df.query("dimension == 'Asian (non-Hispanic)'")
# Out:
#        indicator_id                              indicator_name  \
# 22              103  ACS Family Service Unit Service Recipients
# 34              103  ACS Family Service Unit Service Recipients
# 39              103  ACS Family Service Unit Service Recipients
# 48              103  ACS Family Service Unit Service Recipients
# 96               62                  Adult Families in Shelters
# ...             ...                                         ...
# 17214           108                        Youth in Foster Care
# 17223           108                        Youth in Foster Care
# 17235           112       Youth Leadership Council Participants
# 17239           112       Youth Leadership Council Participants
# 17254           112       Youth Leadership Council Participants
#
#                                       domain  \
# 22             Personal and Community Safety
# 34             Personal and Community Safety
# 39             Personal and Community Safety
# ...
